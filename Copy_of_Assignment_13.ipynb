# %% [markdown]
# <a href="https://colab.research.google.com/github/AliciaW2026/MachineLearning-Assignments/blob/main/Copy_of_Assignment_13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install transformers datasets torch

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_name = "gpt2"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# ...

# %%
def generate_text(prompt, max_length=50, temperature=1.0, top_k=50, top_p=0.95):
    inputs = tokenizer(prompt, return_tensors="pt")

    output = model.generate(
        **inputs,
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        do_sample=True
    )

    return tokenizer.decode(output[0], skip_special_tokens=True)

# %%
print(generate_text("Once upon a time"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time there was no other way out. You must escape, go and find your way back to your father."
#
# As he was speaking he took up this task in the darkness of his own mind. He had never heard of such

# %%
print(generate_text("Once upon a time", max_length=100))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, I had a lot of good things.
#
# But what if I couldn't find the reason the government made this mistake? Is it because I don't want to pay taxes? Or maybe it was just that I don't feel as if there's such an important reason the public shouldn't pay its fair share of taxes – or even if they do.
#
# In order to make matters worse, it seems that I am missing something here. What if I have an idea

# %%
print(generate_text("Once upon a time", temperature=0.5))  # safer
print(generate_text("Once upon a time", temperature=1.2))  # more creative
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, I was at the edge of my seat and I was sitting there and I was like, "This is crazy. This is crazy. This is crazy. This is crazy. This is crazy. This is crazy." I was
# Once upon a time she told the man she had lost a brother, who has since been killed by another person. When the man later asks what happened, he has to listen with what ears he can see. What the brother told her was not good

# %%
print(generate_text("Once upon a time", top_k=10))
print(generate_text("Once upon a time", top_p=0.8))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Once upon a time, a small group of students at the University of North Carolina Wilmington decided that the school would make a mistake in not offering any scholarships to students in need of them.
#
# The students, who are now the faculty of the college
# Once upon a time in history when the greatest man in the world was a mere child of an aristocratic family, the country had suffered an uprising, which took place in a country which had never before been occupied. The rebels were victorious, and with

# %%
print(generate_text("Write a motivational message for a single mom balancing school and life:"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a motivational message for a single mom balancing school and life:
#
# A positive and nurturing environment for kids is not only easy but also a rewarding one to do. Let a child know that his or her own time is in your control, and
