# %% [markdown]
# <a href="https://colab.research.google.com/github/AliciaW2026/MachineLearning-Assignments/blob/AI-Assignments/assignment02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Git and GitHub Assignment 2
#
# This notebook demonstrates basic Git operations.

# %%
def multiply_numbers(a, b):
    return a * b

print(multiply_numbers(3, 4))
# Out:
# 12

# %%
# !git --version
# Out:
# git version 2.34.1

# %%
# !git config --global user.email "your_email@gmail.com"
# !git config --global user.name "Your Name"

# %% [markdown]
# Step 2

# %%
# !git clone https://github.com/AliciaW2026/MachineLearning-Assignments.git
# Out:
# Cloning into 'MachineLearning-Assignments'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 33 (delta 8), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (33/33), 545.70 KiB | 5.68 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
# !ls
# Out:
# Assignment_14_Ethical_AI_Fairness_Explainability.ipynb	README_Assignment_14.md
# Assignment15.ipynb					README.md
# Generative_AI_Assignment.ipynb

# %%
# %cd MachineLearning-Assignments
# Out:
# [Errno 2] No such file or directory: 'MachineLearning-Assignments'
# /content/MachineLearning-Assignments

# %%
# !ls
# Out:
# Assignment_14_Ethical_AI_Fairness_Explainability.ipynb	README_Assignment_14.md
# Assignment15.ipynb					README.md
# Generative_AI_Assignment.ipynb
